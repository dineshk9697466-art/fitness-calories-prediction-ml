# %% [markdown]
# # Step - 1: Import and Inspect Data...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dkdee\Downloads\calories_burned_unclean_1000.csv")

# %%
df
# Out:
#      Age  Gender  Weight_kg  Height_cm Workout_Duration_min Heart_Rate_avg  \
# 0     57  Female       75.4      167.0                    0            107
# 1     60  Female       46.0      162.9                   29             88
# 2     29  Female       48.9      178.7                   14            117
# 3     19   Other       55.0      180.8                   15             94
# 4     36  Female       81.9        NaN                   15            104
# ..   ...     ...        ...        ...                  ...            ...
# 995   25    Male        NaN      182.8                    5            102
# 996   53  Female       54.3      162.8                  NaN             89
# 997   30    Male       70.2      180.1                   24            129
# 998   46  Female       83.3      172.6                   49             96
# 999   54  Female       67.6      185.3                   32             84
#
#      Steps_Count  Sleep_Hours  Water_Intake_Liters  Calories_Burned
# 0         7668.0          7.0                 1.36             22.3
# 1        11857.0          8.1                 1.69             84.5
# 2            NaN          7.3                 2.51            105.8
# 3            NaN          7.8                 1.60             26.4
# 4         -325.0          4.6                 1.08             64.0
# ..           ...          ...                  ...              ...
# 995        748.0          6.8                 1.77             32.1
# 996       2787.0          7.0                 1.63             76.7
# 997       4888.0          8.4                -0.08            151.6
# 998       7314.0          5.8                  NaN            326.4
# 999       4148.0          NaN                 2.20            103.7
#
# [1000 rows x 10 columns]

# %%
#show first 5 rows
df.head()
# Out:
#    Age  Gender  Weight_kg  Height_cm Workout_Duration_min Heart_Rate_avg  \
# 0   57  Female       75.4      167.0                    0            107
# 1   60  Female       46.0      162.9                   29             88
# 2   29  Female       48.9      178.7                   14            117
# 3   19   Other       55.0      180.8                   15             94
# 4   36  Female       81.9        NaN                   15            104
#
#    Steps_Count  Sleep_Hours  Water_Intake_Liters  Calories_Burned
# 0       7668.0          7.0                 1.36             22.3
# 1      11857.0          8.1                 1.69             84.5
# 2          NaN          7.3                 2.51            105.8
# 3          NaN          7.8                 1.60             26.4
# 4       -325.0          4.6                 1.08             64.0

# %%
# it shows how many columns and rows in numbers
df.shape
# Out:
# (1000, 10)

# %%
# show data types
df.dtypes
# Out:
# Age                       int64
# Gender                   object
# Weight_kg               float64
# Height_cm               float64
# Workout_Duration_min     object
# Heart_Rate_avg           object
# Steps_Count             float64
# Sleep_Hours             float64
# Water_Intake_Liters     float64
# Calories_Burned         float64
# dtype: object

# %%
# check missing values
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Weight_kg               81
# Height_cm               83
# Workout_Duration_min    94
# Heart_Rate_avg          91
# Steps_Count             75
# Sleep_Hours             65
# Water_Intake_Liters     88
# Calories_Burned          0
# dtype: int64

# %% [markdown]
# # Step 2: check and fix Data Types

# %%
# convert the wrong data type values into NaN or numbers
df['Workout_Duration_min'] = pd.to_numeric(df['Workout_Duration_min'],errors = 'coerce')
df['Heart_Rate_avg'] = pd.to_numeric(df['Heart_Rate_avg'],errors = 'coerce')

# %%
# check after the conversion
df.dtypes
# Out:
# Age                       int64
# Gender                   object
# Weight_kg               float64
# Height_cm               float64
# Workout_Duration_min    float64
# Heart_Rate_avg          float64
# Steps_Count             float64
# Sleep_Hours             float64
# Water_Intake_Liters     float64
# Calories_Burned         float64
# dtype: object

# %%
# check missing values
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Weight_kg               81
# Height_cm               83
# Workout_Duration_min    99
# Heart_Rate_avg          96
# Steps_Count             75
# Sleep_Hours             65
# Water_Intake_Liters     88
# Calories_Burned          0
# dtype: int64

# %% [markdown]
# # Step 3: fill the missing values

# %%
#numeric cols handling by median

numeric_cols = df.select_dtypes(include=['int64','float64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# categorical column handling by mode

categorical_col = df.select_dtypes(include =['object']).columns
for col in categorical_col:
     df[col]=df[col].fillna(df[col].mode()[0])

# %%
# after check if any missing value are there
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Weight_kg               0
# Height_cm               0
# Workout_Duration_min    0
# Heart_Rate_avg          0
# Steps_Count             0
# Sleep_Hours             0
# Water_Intake_Liters     0
# Calories_Burned         0
# dtype: int64

# %% [markdown]
# # Step 4: Outlier Detection and Handling

# %%
import numpy as np

# %%
numeric_cols = df.select_dtypes(include = ['number']).columns

for col in numeric_cols:
    q1 =df[col].quantile(0.25)
    q2 =df[col].quantile(0.75)
    iqr =q2 - q1  #Interquartile Range

    lower_lim =q1 - 1.5 * iqr
    upper_lim =q2 + 1.5 * iqr
    #remove outliears
    df = df[(df[col] >= lower_lim) & (df[col] <= upper_lim)]

print("Outliers handled successfully!")
# Out:
# Outliers handled successfully!

# %% [markdown]
# # Step 5: EDA (Explotary Data Analysis)

# %%
#summary statistics
df.describe()
# Out:
#               Age   Weight_kg   Height_cm  Workout_Duration_min  \
# count  773.000000  773.000000  773.000000            773.000000
# mean    40.880983   70.083182  170.052264             20.227684
# std     13.446644   13.084083    8.999366             14.960913
# min     18.000000   35.600000  147.500000              0.000000
# 25%     29.000000   61.400000  164.000000              8.000000
# 50%     41.000000   70.400000  170.000000             18.000000
# 75%     52.000000   78.200000  175.800000             28.000000
# max     64.000000  106.200000  193.200000             75.000000
#
#        Heart_Rate_avg   Steps_Count  Sleep_Hours  Water_Intake_Liters  \
# count      773.000000    773.000000   773.000000           773.000000
# mean        94.724450   5775.862872     6.964036             1.816494
# std         13.537527   3129.606174     1.186769             0.539513
# min         59.000000  -2524.000000     3.700000             0.360000
# 25%         86.000000   3727.000000     6.100000             1.460000
# 50%         95.000000   5808.000000     7.000000             1.790000
# 75%        104.000000   7770.000000     7.800000             2.170000
# max        131.000000  14182.000000    10.300000             3.240000
#
#        Calories_Burned
# count       773.000000
# mean         87.154204
# std          79.553007
# min         -73.800000
# 25%          29.800000
# 50%          70.800000
# 75%         128.200000
# max         326.500000

# %%
import matplotlib.pyplot as plt
#histogram graph

df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
#boxplot
plt.figure(figsize=(12, 6))
df.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10, 7))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Step 6: Encode categorical Data(Gender)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %% [markdown]
# # Step 7: Train - Test split

# %%
from sklearn.model_selection import train_test_split

# X = all columns except Calories_Burned
#drop mean is except that
x = df.drop('Calories_Burned', axis=1)

# y = the target column
y = df['Calories_Burned']

# Train-test split (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (618, 9)
# x_test shape: (155, 9)
# y_train shape: (618,)
# y_test shape: (155,)

# %% [markdown]
# # Step 8: Build Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating a object for LinearRegression
model = LinearRegression()

# train the model 

model.fit(x_train, y_train)

# predict on test data

y_pred =model.predict(x_test)

# %% [markdown]
# # Step 9: Model Evaluation
#      MAE -> Mean Absolute Error
#      MSE -> Mean squared Error
#      RMSE -> Root Mean Squared Error
#      R(square) -> Accuracy of Model

# %%
#import functions to calculate errors
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse =np.sqrt(mse)
r2 = r2_score(y_test,y_pred)

# %%
#primt results

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 31.66434773803952
# Mean Squared Error (MSE): 1831.5733320437537
# Root Mean Squared Error (RMSE): 42.79688460675325
# R² Score: 0.7612222422240582
